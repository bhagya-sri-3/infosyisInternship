# %%
az*----------------------------------------------------------!pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
data = pd.read_csv("telecom_churn_data.csv")

# %%
print(data.head())
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 1     7001865778        109             0.0             0.0             0.0
# 2     7001625959        109             0.0             0.0             0.0
# 3     7001204172        109             0.0             0.0             0.0
# 4     7000142493        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# 1            6/30/2014            7/31/2014            8/31/2014
# 2            6/30/2014            7/31/2014            8/31/2014
# 3            6/30/2014            7/31/2014            8/31/2014
# 4            6/30/2014            7/31/2014            8/31/2014
#
#   last_date_of_month_9   arpu_6  ...  sachet_3g_9  fb_user_6  fb_user_7  \
# ...

# %%
import pandas as pd
data=pd.DataFrame({'aon':['10','20','30','40','50']})
print("Before conversion:")
print(data.dtypes)
data['aon'] = pd.to_numeric(data['aon'], errors='coerce')
print("\nAfter conversion:")
print(data.dtypes)
# Out:
# Before conversion:
# aon    object
# dtype: object
#
# After conversion:
# aon    int64
# dtype: object

# %%
data_without_duplicates = data.drop_duplicates()
print(data_without_duplicates)
# Out:
#        mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  \
# 0         7000842753        109             0.0             0.0
# 1         7001865778        109             0.0             0.0
# 2         7001625959        109             0.0             0.0
# 3         7001204172        109             0.0             0.0
# 4         7000142493        109             0.0             0.0
# ...              ...        ...             ...             ...
# 99994     7001548952        109             0.0             0.0
# 99995     7000607688        109             0.0             0.0
# 99996     7000087541        109             0.0             0.0
# 99997     7000498689        109             0.0             0.0
# 99998     7001905007        109             0.0             0.0
#
#        loc_ic_t2o_mou last_date_of_month_6 last_date_of_month_7  \
# 0                 0.0            6/30/2014            7/31/2014
# 1                 0.0            6/30/2014            7/31/2014
# ...

# %%
import pandas as pd
# Load the dataset into a DataFrame
df = pd.read_csv(r"C:\Users\bhagy\Downloads\Desktop\telecom_churn_data.csv")
# Identify columns with unique values
unique_columns = []
for column in df.columns:
    if df[column].nunique() == 1:
        unique_columns.append(column)
# Remove columns with unique values
df.drop(unique_columns, axis=1, inplace=True)

# %%
print(df.head())
print(df.tail())
# Out:
#    mobile_number   arpu_6   arpu_7   arpu_8   arpu_9  onnet_mou_6  \
# 0     7000842753  197.385  214.816  213.803   21.100          NaN
# 1     7001865778   34.047  355.074  268.321   86.285        24.11
# 2     7001625959  167.690  189.058  210.226  290.714        11.54
# 3     7001204172  221.338  251.102  508.054  389.500        99.91
# 4     7000142493  261.636  309.876  238.174  163.426        50.31
#
#    onnet_mou_7  onnet_mou_8  onnet_mou_9  offnet_mou_6  ...  sachet_3g_9  \
# 0          NaN         0.00          NaN           NaN  ...            0
# 1        78.68         7.68        18.34         15.74  ...            0
# 2        55.24        37.26        74.81        143.33  ...            0
# 3        54.39       310.98       241.71        123.31  ...            0
# 4       149.44        83.89        58.78         76.96  ...            0
#
#    fb_user_6  fb_user_7  fb_user_8  fb_user_9   aon  aug_vbc_3g  jul_vbc_3g  \
# ...

# %%
import pandas as pd

# Load the dataset into a DataFrame
df = pd.read_csv(r"C:\Users\bhagy\Downloads\Desktop\telecom_churn_data.csv")
zero_variance_columns= []
for column in df.columns:
    if df[column].nunique() == 1:
        zero_variance_columns.append(column)
df.drop(zero_variance_columns, axis=1,inplace=True)

# %%
print(df.head())
# Out:
#    mobile_number   arpu_6   arpu_7   arpu_8   arpu_9  onnet_mou_6  \
# 0     7000842753  197.385  214.816  213.803   21.100          NaN
# 1     7001865778   34.047  355.074  268.321   86.285        24.11
# 2     7001625959  167.690  189.058  210.226  290.714        11.54
# 3     7001204172  221.338  251.102  508.054  389.500        99.91
# 4     7000142493  261.636  309.876  238.174  163.426        50.31
#
#    onnet_mou_7  onnet_mou_8  onnet_mou_9  offnet_mou_6  ...  sachet_3g_9  \
# 0          NaN         0.00          NaN           NaN  ...            0
# 1        78.68         7.68        18.34         15.74  ...            0
# 2        55.24        37.26        74.81        143.33  ...            0
# 3        54.39       310.98       241.71        123.31  ...            0
# 4       149.44        83.89        58.78         76.96  ...            0
#
#    fb_user_6  fb_user_7  fb_user_8  fb_user_9   aon  aug_vbc_3g  jul_vbc_3g  \
# ...

# %%
print(data.tail())
# Out:
#    aon
# 0   10
# 1   20
# 2   30
# 3   40
# 4   50

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Load your dataset into 'data'
data = pd.read_csv('telecom_churn_data.csv')

# Select only numeric columns
numeric_columns = data.select_dtypes(include=['int64', 'float64'])

# Loop through each numeric column of the DataFrame and create box plots
for col in numeric_columns.columns:
    sns.boxplot(data=data[col])
    plt.title('Box plot of {}'.format(col))
    plt.show()

# %%
import pandas as pd
import numpy as np
# Load your data into a DataFrame
data = pd.read_excel('')  # Replace 'your_excel_file.xlsx' with your file path

# Identify unique value columns
unique_value_cols = data.columns[data.nunique() == data.shape[0]]  # Count unique values per column, check if it equals number of rows

# Remove unique value columns
data = data.drop(unique_value_cols, axis=1)

# Save the DataFrame to a new Excel file
data.to_excel('telecom_churn_dataset.xlsx', index=False)  # Replace 'output_excel_file.xlsx' with desired output file name
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 4
#       2 import numpy as np
#       3 # Load your data into a DataFrame
# ----> 4 data = pd.read_excel('telecom_churn_dataset.xlsx')  # Replace 'your_excel_file.xlsx' with your file path
#       6 # Identify unique value columns
#       7 unique_value_cols = data.columns[data.nunique() == data.shape[0]]  # Count unique values per column, check if it equals number of rows
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
# ...
